# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
from torchvision import transforms, utils, models

import matplotlib.pyplot as plt
import numpy as np

from functools import partial, reduce
from typing import List
from pytorch_i3d.pytorch_i3d import InceptionI3d
from datasetMVAD import MVADDataset
from transforms import mvad_basic_transform
from extract_feature import Extractor
import os

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')

# %%
#i3d = InceptionI3d(157, end_module='Mixed_5c')
#i3d.load_state_dict(torch.load('./pytorch_i3d/models/rgb_charades.pt'), strict=False)
i3d = InceptionI3d(400, end_module='Mixed_5c')
i3d.load_state_dict(torch.load('./pytorch_i3d/models/rgb_kinetics.pth'), strict=True)
i3d.to(device)
i3d.eval()
# Out:
# InceptionI3d(
#   (avg_pool): AvgPool3d(kernel_size=[2, 7, 7], stride=(1, 1, 1), padding=0)
#   (dropout): Dropout(p=0.5)
#   (logits): Unit3D(
#     (conv3d): Conv3d(1024, 400, kernel_size=[1, 1, 1], stride=(1, 1, 1))
#   )
#   (Conv3d_1a_7x7): Unit3D(
#     (conv3d): Conv3d(3, 64, kernel_size=[7, 7, 7], stride=(2, 2, 2), bias=False)
#     (bn): BatchNorm3d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   )
#   (MaxPool3d_2a_3x3): MaxPool3dSamePadding(kernel_size=[1, 3, 3], stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (Conv3d_2b_1x1): Unit3D(
#     (conv3d): Conv3d(64, 64, kernel_size=[1, 1, 1], stride=(1, 1, 1), bias=False)
#     (bn): BatchNorm3d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   )
#   (Conv3d_2c_3x3): Unit3D(
#     (conv3d): Conv3d(64, 192, kernel_size=[3, 3, 3], stride=(1, 1, 1), bias=False)
#     (bn): BatchNorm3d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   )
# ...

# %%
MVAD_PATH = '../MVAD'
MVAD_CORPUS_PATH = os.path.join(MVAD_PATH, 'corpus_M-VAD_test.txt')
MVAD_VIDEOS_PATH = os.path.join(MVAD_PATH, 'video')
transform = mvad_basic_transform()
test_dataset = MVADDataset(MVAD_VIDEOS_PATH, MVAD_CORPUS_PATH, train=False, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=True, num_workers=4)

# %%
MVAD_TEST_SAVE_PATH = os.path.join(MVAD_PATH, 'I3D_rgb_kinetics', 'test')

# %%
test_extractor = Extractor(i3d, MVAD_TEST_SAVE_PATH, gpu_device=device)
error_files = test_extractor.extract_feature_from_loader(test_loader)
# Out:
# 100 have extracted - 68s
# 200 have extracted - 137s
# 300 have extracted - 202s
# 400 have extracted - 265s
# 500 have extracted - 330s
# 600 have extracted - 396s
# 700 have extracted - 468s
# 800 have extracted - 538s
# 900 have extracted - 600s
# 1000 have extracted - 667s
# 1100 have extracted - 733s
# 1200 have extracted - 801s
# 1300 have extracted - 867s
# 1400 have extracted - 932s
# 1500 have extracted - 1003s
# 1600 have extracted - 1067s
# 1700 have extracted - 1133s
# 1800 have extracted - 1197s
# 1900 have extracted - 1264s
# 2000 have extracted - 1335s
# 2100 have extracted - 1397s
# 2200 have extracted - 1461s
# 2300 have extracted - 1526s
# 2400 have extracted - 1589s
# 2500 have extracted - 1647s
# 2600 have extracted - 1713s
# 2700 have extracted - 1774s
# 2800 have extracted - 1845s
# 2900 have extracted - 1915s

# %%
print(error_files)
# Out:
# []
