# %%
import re
import torch
from functools import partial, reduce

# %%
a = torch.load('./pytorch_i3d/models/flow_charades.pt')
b = torch.load('./pytorch_i3d/models/flow_kinetics_origin.pth')

# %%
a_keys = a.keys()
b_keys = b.keys()
a_set = set(map(lambda var: var.split('.')[0], list(a.keys())))
b_set = set(map(lambda var: var.split('.')[0], list(b.keys())))

# %%
a_set.remove('logits')

# %%
a_set
# Out:
# {'Conv3d_1a_7x7',
#  'Conv3d_2b_1x1',
#  'Conv3d_2c_3x3',
#  'Mixed_3b',
#  'Mixed_3c',
#  'Mixed_4b',
#  'Mixed_4c',
#  'Mixed_4d',
#  'Mixed_4e',
#  'Mixed_4f',
#  'Mixed_5b',
#  'Mixed_5c'}

# %%
b_set
# Out:
# {'conv3d_0c_1x1',
#  'conv3d_1a_7x7',
#  'conv3d_2b_1x1',
#  'conv3d_2c_3x3',
#  'mixed_3b',
#  'mixed_3c',
#  'mixed_4b',
#  'mixed_4c',
#  'mixed_4d',
#  'mixed_4e',
#  'mixed_4f',
#  'mixed_5b',
#  'mixed_5c'}

# %%
list(filter(lambda var: re.match('logit', var), list(a_keys)))
# Out:
# ['logits.conv3d.weight', 'logits.conv3d.bias']

# %%
list(filter(lambda var: re.match('Mixed_5c', var.capitalize()), list(b_keys)))
# Out:
# ['mixed_5c.branch_0.conv3d.weight',
#  'mixed_5c.branch_0.batch3d.weight',
#  'mixed_5c.branch_0.batch3d.bias',
#  'mixed_5c.branch_0.batch3d.running_mean',
#  'mixed_5c.branch_0.batch3d.running_var',
#  'mixed_5c.branch_1.0.conv3d.weight',
#  'mixed_5c.branch_1.0.batch3d.weight',
#  'mixed_5c.branch_1.0.batch3d.bias',
#  'mixed_5c.branch_1.0.batch3d.running_mean',
#  'mixed_5c.branch_1.0.batch3d.running_var',
#  'mixed_5c.branch_1.1.conv3d.weight',
#  'mixed_5c.branch_1.1.batch3d.weight',
#  'mixed_5c.branch_1.1.batch3d.bias',
#  'mixed_5c.branch_1.1.batch3d.running_mean',
#  'mixed_5c.branch_1.1.batch3d.running_var',
#  'mixed_5c.branch_2.0.conv3d.weight',
#  'mixed_5c.branch_2.0.batch3d.weight',
#  'mixed_5c.branch_2.0.batch3d.bias',
#  'mixed_5c.branch_2.0.batch3d.running_mean',
#  'mixed_5c.branch_2.0.batch3d.running_var',
#  'mixed_5c.branch_2.1.conv3d.weight',
#  'mixed_5c.branch_2.1.batch3d.weight',
#  'mixed_5c.branch_2.1.batch3d.bias',
#  'mixed_5c.branch_2.1.batch3d.running_mean',
#  'mixed_5c.branch_2.1.batch3d.running_var',
#  'mixed_5c.branch_3.1.conv3d.weight',
#  'mixed_5c.branch_3.1.batch3d.weight',
#  'mixed_5c.branch_3.1.batch3d.bias',
#  'mixed_5c.branch_3.1.batch3d.running_mean',
#  'mixed_5c.branch_3.1.batch3d.running_var']

# %%
def update_keys(pattern, new_b_dict):
    a_matched = list(filter(lambda var: re.match(pattern, var), list(a_keys)))
    b_matched = list(filter(lambda var: re.match(pattern, var.capitalize()), list(b_keys)))
    for a_key, b_key in zip(a_matched, b_matched):
        print('{:30s} -> {:30s}'.format(a_key, b_key))
        print()
        
        if a_key.split('.')[-1] != b_key.split('.')[-1]:
            print('Not matched1')
            
        if a_key.split('.')[-2][0] != b_key.split('.')[-2][0]:
            print('Not matched2')
            
        value = b[b_key]
        new_b_dict[a_key] = value
            
    return new_b_dict

# %%
new_b_dict = {}
for pattern in a_set:
    update_keys(pattern, new_b_dict)
# Out:
# Mixed_3b.b0.conv3d.weight      -> mixed_3b.branch_0.conv3d.weight
#
# Mixed_3b.b0.bn.weight          -> mixed_3b.branch_0.batch3d.weight
#
# Mixed_3b.b0.bn.bias            -> mixed_3b.branch_0.batch3d.bias
#
# Mixed_3b.b0.bn.running_mean    -> mixed_3b.branch_0.batch3d.running_mean
#
# Mixed_3b.b0.bn.running_var     -> mixed_3b.branch_0.batch3d.running_var
#
# Mixed_3b.b1a.conv3d.weight     -> mixed_3b.branch_1.0.conv3d.weight
#
# Mixed_3b.b1a.bn.weight         -> mixed_3b.branch_1.0.batch3d.weight
#
# Mixed_3b.b1a.bn.bias           -> mixed_3b.branch_1.0.batch3d.bias
#
# Mixed_3b.b1a.bn.running_mean   -> mixed_3b.branch_1.0.batch3d.running_mean
#
# Mixed_3b.b1a.bn.running_var    -> mixed_3b.branch_1.0.batch3d.running_var
#
# Mixed_3b.b1b.conv3d.weight     -> mixed_3b.branch_1.1.conv3d.weight
#
# Mixed_3b.b1b.bn.weight         -> mixed_3b.branch_1.1.batch3d.weight
#
# Mixed_3b.b1b.bn.bias           -> mixed_3b.branch_1.1.batch3d.bias
#
# Mixed_3b.b1b.bn.running_mean   -> mixed_3b.branch_1.1.batch3d.running_mean
#
# Mixed_3b.b1b.bn.running_var    -> mixed_3b.branch_1.1.batch3d.running_var
#
# Mixed_3b.b2a.conv3d.weight     -> mixed_3b.branch_2.0.conv3d.weight
#
# Mixed_3b.b2a.bn.weight         -> mixed_3b.branch_2.0.batch3d.weight
#
# Mixed_3b.b2a.bn.bias           -> mixed_3b.branch_2.0.batch3d.bias
#
# Mixed_3b.b2a.bn.running_mean   -> mixed_3b.branch_2.0.batch3d.running_mean
#
# Mixed_3b.b2a.bn.running_var    -> mixed_3b.branch_2.0.batch3d.running_var
#
# Mixed_3b.b2b.conv3d.weight     -> mixed_3b.branch_2.1.conv3d.weight
#
# Mixed_3b.b2b.bn.weight         -> mixed_3b.branch_2.1.batch3d.weight
#
# Mixed_3b.b2b.bn.bias           -> mixed_3b.branch_2.1.batch3d.bias
#
# Mixed_3b.b2b.bn.running_mean   -> mixed_3b.branch_2.1.batch3d.running_mean
#
# Mixed_3b.b2b.bn.running_var    -> mixed_3b.branch_2.1.batch3d.running_var
#
# Mixed_3b.b3b.conv3d.weight     -> mixed_3b.branch_3.1.conv3d.weight
#
# Mixed_3b.b3b.bn.weight         -> mixed_3b.branch_3.1.batch3d.weight
#
# Mixed_3b.b3b.bn.bias           -> mixed_3b.branch_3.1.batch3d.bias
#
# Mixed_3b.b3b.bn.running_mean   -> mixed_3b.branch_3.1.batch3d.running_mean
#
# Mixed_3b.b3b.bn.running_var    -> mixed_3b.branch_3.1.batch3d.running_var
#
# Mixed_4e.b0.conv3d.weight      -> mixed_4e.branch_0.conv3d.weight
#
# Mixed_4e.b0.bn.weight          -> mixed_4e.branch_0.batch3d.weight
#
# Mixed_4e.b0.bn.bias            -> mixed_4e.branch_0.batch3d.bias
#
# Mixed_4e.b0.bn.running_mean    -> mixed_4e.branch_0.batch3d.running_mean
#
# Mixed_4e.b0.bn.running_var     -> mixed_4e.branch_0.batch3d.running_var
#
# Mixed_4e.b1a.conv3d.weight     -> mixed_4e.branch_1.0.conv3d.weight
#
# Mixed_4e.b1a.bn.weight         -> mixed_4e.branch_1.0.batch3d.weight
#
# Mixed_4e.b1a.bn.bias           -> mixed_4e.branch_1.0.batch3d.bias
#
# Mixed_4e.b1a.bn.running_mean   -> mixed_4e.branch_1.0.batch3d.running_mean
#
# Mixed_4e.b1a.bn.running_var    -> mixed_4e.branch_1.0.batch3d.running_var
#
# Mixed_4e.b1b.conv3d.weight     -> mixed_4e.branch_1.1.conv3d.weight
#
# Mixed_4e.b1b.bn.weight         -> mixed_4e.branch_1.1.batch3d.weight
#
# Mixed_4e.b1b.bn.bias           -> mixed_4e.branch_1.1.batch3d.bias
#
# Mixed_4e.b1b.bn.running_mean   -> mixed_4e.branch_1.1.batch3d.running_mean
#
# Mixed_4e.b1b.bn.running_var    -> mixed_4e.branch_1.1.batch3d.running_var
#
# Mixed_4e.b2a.conv3d.weight     -> mixed_4e.branch_2.0.conv3d.weight
#
# Mixed_4e.b2a.bn.weight         -> mixed_4e.branch_2.0.batch3d.weight
#
# Mixed_4e.b2a.bn.bias           -> mixed_4e.branch_2.0.batch3d.bias
#
# Mixed_4e.b2a.bn.running_mean   -> mixed_4e.branch_2.0.batch3d.running_mean
#
# Mixed_4e.b2a.bn.running_var    -> mixed_4e.branch_2.0.batch3d.running_var
#
# Mixed_4e.b2b.conv3d.weight     -> mixed_4e.branch_2.1.conv3d.weight
#
# Mixed_4e.b2b.bn.weight         -> mixed_4e.branch_2.1.batch3d.weight
#
# Mixed_4e.b2b.bn.bias           -> mixed_4e.branch_2.1.batch3d.bias
#
# Mixed_4e.b2b.bn.running_mean   -> mixed_4e.branch_2.1.batch3d.running_mean
#
# Mixed_4e.b2b.bn.running_var    -> mixed_4e.branch_2.1.batch3d.running_var
#
# Mixed_4e.b3b.conv3d.weight     -> mixed_4e.branch_3.1.conv3d.weight
#
# Mixed_4e.b3b.bn.weight         -> mixed_4e.branch_3.1.batch3d.weight
#
# Mixed_4e.b3b.bn.bias           -> mixed_4e.branch_3.1.batch3d.bias
#
# Mixed_4e.b3b.bn.running_mean   -> mixed_4e.branch_3.1.batch3d.running_mean
#
# Mixed_4e.b3b.bn.running_var    -> mixed_4e.branch_3.1.batch3d.running_var
#
# Mixed_4d.b0.conv3d.weight      -> mixed_4d.branch_0.conv3d.weight
#
# Mixed_4d.b0.bn.weight          -> mixed_4d.branch_0.batch3d.weight
#
# Mixed_4d.b0.bn.bias            -> mixed_4d.branch_0.batch3d.bias
#
# Mixed_4d.b0.bn.running_mean    -> mixed_4d.branch_0.batch3d.running_mean
#
# Mixed_4d.b0.bn.running_var     -> mixed_4d.branch_0.batch3d.running_var
#
# Mixed_4d.b1a.conv3d.weight     -> mixed_4d.branch_1.0.conv3d.weight
#
# Mixed_4d.b1a.bn.weight         -> mixed_4d.branch_1.0.batch3d.weight
#
# Mixed_4d.b1a.bn.bias           -> mixed_4d.branch_1.0.batch3d.bias
#
# Mixed_4d.b1a.bn.running_mean   -> mixed_4d.branch_1.0.batch3d.running_mean
#
# Mixed_4d.b1a.bn.running_var    -> mixed_4d.branch_1.0.batch3d.running_var
#
# Mixed_4d.b1b.conv3d.weight     -> mixed_4d.branch_1.1.conv3d.weight
#
# Mixed_4d.b1b.bn.weight         -> mixed_4d.branch_1.1.batch3d.weight
#
# Mixed_4d.b1b.bn.bias           -> mixed_4d.branch_1.1.batch3d.bias
#
# Mixed_4d.b1b.bn.running_mean   -> mixed_4d.branch_1.1.batch3d.running_mean
#
# Mixed_4d.b1b.bn.running_var    -> mixed_4d.branch_1.1.batch3d.running_var
#
# Mixed_4d.b2a.conv3d.weight     -> mixed_4d.branch_2.0.conv3d.weight
#
# Mixed_4d.b2a.bn.weight         -> mixed_4d.branch_2.0.batch3d.weight
#
# Mixed_4d.b2a.bn.bias           -> mixed_4d.branch_2.0.batch3d.bias
#
# Mixed_4d.b2a.bn.running_mean   -> mixed_4d.branch_2.0.batch3d.running_mean
#
# Mixed_4d.b2a.bn.running_var    -> mixed_4d.branch_2.0.batch3d.running_var
#
# Mixed_4d.b2b.conv3d.weight     -> mixed_4d.branch_2.1.conv3d.weight
#
# Mixed_4d.b2b.bn.weight         -> mixed_4d.branch_2.1.batch3d.weight
#
# Mixed_4d.b2b.bn.bias           -> mixed_4d.branch_2.1.batch3d.bias
#
# Mixed_4d.b2b.bn.running_mean   -> mixed_4d.branch_2.1.batch3d.running_mean
#
# Mixed_4d.b2b.bn.running_var    -> mixed_4d.branch_2.1.batch3d.running_var
#
# Mixed_4d.b3b.conv3d.weight     -> mixed_4d.branch_3.1.conv3d.weight
#
# Mixed_4d.b3b.bn.weight         -> mixed_4d.branch_3.1.batch3d.weight
#
# Mixed_4d.b3b.bn.bias           -> mixed_4d.branch_3.1.batch3d.bias
#
# Mixed_4d.b3b.bn.running_mean   -> mixed_4d.branch_3.1.batch3d.running_mean
#
# Mixed_4d.b3b.bn.running_var    -> mixed_4d.branch_3.1.batch3d.running_var
#
# Mixed_5c.b0.conv3d.weight      -> mixed_5c.branch_0.conv3d.weight
#
# Mixed_5c.b0.bn.weight          -> mixed_5c.branch_0.batch3d.weight
#
# Mixed_5c.b0.bn.bias            -> mixed_5c.branch_0.batch3d.bias
#
# Mixed_5c.b0.bn.running_mean    -> mixed_5c.branch_0.batch3d.running_mean
#
# Mixed_5c.b0.bn.running_var     -> mixed_5c.branch_0.batch3d.running_var
#
# Mixed_5c.b1a.conv3d.weight     -> mixed_5c.branch_1.0.conv3d.weight
#
# Mixed_5c.b1a.bn.weight         -> mixed_5c.branch_1.0.batch3d.weight
#
# Mixed_5c.b1a.bn.bias           -> mixed_5c.branch_1.0.batch3d.bias
#
# Mixed_5c.b1a.bn.running_mean   -> mixed_5c.branch_1.0.batch3d.running_mean
#
# Mixed_5c.b1a.bn.running_var    -> mixed_5c.branch_1.0.batch3d.running_var
#
# Mixed_5c.b1b.conv3d.weight     -> mixed_5c.branch_1.1.conv3d.weight
#
# Mixed_5c.b1b.bn.weight         -> mixed_5c.branch_1.1.batch3d.weight
#
# Mixed_5c.b1b.bn.bias           -> mixed_5c.branch_1.1.batch3d.bias
#
# Mixed_5c.b1b.bn.running_mean   -> mixed_5c.branch_1.1.batch3d.running_mean
#
# Mixed_5c.b1b.bn.running_var    -> mixed_5c.branch_1.1.batch3d.running_var
#
# Mixed_5c.b2a.conv3d.weight     -> mixed_5c.branch_2.0.conv3d.weight
#
# Mixed_5c.b2a.bn.weight         -> mixed_5c.branch_2.0.batch3d.weight
#
# Mixed_5c.b2a.bn.bias           -> mixed_5c.branch_2.0.batch3d.bias
#
# Mixed_5c.b2a.bn.running_mean   -> mixed_5c.branch_2.0.batch3d.running_mean
#
# Mixed_5c.b2a.bn.running_var    -> mixed_5c.branch_2.0.batch3d.running_var
#
# Mixed_5c.b2b.conv3d.weight     -> mixed_5c.branch_2.1.conv3d.weight
#
# Mixed_5c.b2b.bn.weight         -> mixed_5c.branch_2.1.batch3d.weight
#
# Mixed_5c.b2b.bn.bias           -> mixed_5c.branch_2.1.batch3d.bias
#
# Mixed_5c.b2b.bn.running_mean   -> mixed_5c.branch_2.1.batch3d.running_mean
#
# Mixed_5c.b2b.bn.running_var    -> mixed_5c.branch_2.1.batch3d.running_var
#
# Mixed_5c.b3b.conv3d.weight     -> mixed_5c.branch_3.1.conv3d.weight
#
# Mixed_5c.b3b.bn.weight         -> mixed_5c.branch_3.1.batch3d.weight
#
# Mixed_5c.b3b.bn.bias           -> mixed_5c.branch_3.1.batch3d.bias
#
# Mixed_5c.b3b.bn.running_mean   -> mixed_5c.branch_3.1.batch3d.running_mean
#
# Mixed_5c.b3b.bn.running_var    -> mixed_5c.branch_3.1.batch3d.running_var
#
# Mixed_4b.b0.conv3d.weight      -> mixed_4b.branch_0.conv3d.weight
#
# Mixed_4b.b0.bn.weight          -> mixed_4b.branch_0.batch3d.weight
#
# Mixed_4b.b0.bn.bias            -> mixed_4b.branch_0.batch3d.bias
#
# Mixed_4b.b0.bn.running_mean    -> mixed_4b.branch_0.batch3d.running_mean
#
# Mixed_4b.b0.bn.running_var     -> mixed_4b.branch_0.batch3d.running_var
#
# Mixed_4b.b1a.conv3d.weight     -> mixed_4b.branch_1.0.conv3d.weight
#
# Mixed_4b.b1a.bn.weight         -> mixed_4b.branch_1.0.batch3d.weight
#
# Mixed_4b.b1a.bn.bias           -> mixed_4b.branch_1.0.batch3d.bias
#
# Mixed_4b.b1a.bn.running_mean   -> mixed_4b.branch_1.0.batch3d.running_mean
#
# Mixed_4b.b1a.bn.running_var    -> mixed_4b.branch_1.0.batch3d.running_var
#
# Mixed_4b.b1b.conv3d.weight     -> mixed_4b.branch_1.1.conv3d.weight
#
# Mixed_4b.b1b.bn.weight         -> mixed_4b.branch_1.1.batch3d.weight
#
# Mixed_4b.b1b.bn.bias           -> mixed_4b.branch_1.1.batch3d.bias
#
# Mixed_4b.b1b.bn.running_mean   -> mixed_4b.branch_1.1.batch3d.running_mean
#
# Mixed_4b.b1b.bn.running_var    -> mixed_4b.branch_1.1.batch3d.running_var
#
# Mixed_4b.b2a.conv3d.weight     -> mixed_4b.branch_2.0.conv3d.weight
#
# Mixed_4b.b2a.bn.weight         -> mixed_4b.branch_2.0.batch3d.weight
#
# Mixed_4b.b2a.bn.bias           -> mixed_4b.branch_2.0.batch3d.bias
#
# Mixed_4b.b2a.bn.running_mean   -> mixed_4b.branch_2.0.batch3d.running_mean
#
# Mixed_4b.b2a.bn.running_var    -> mixed_4b.branch_2.0.batch3d.running_var
#
# Mixed_4b.b2b.conv3d.weight     -> mixed_4b.branch_2.1.conv3d.weight
#
# Mixed_4b.b2b.bn.weight         -> mixed_4b.branch_2.1.batch3d.weight
#
# Mixed_4b.b2b.bn.bias           -> mixed_4b.branch_2.1.batch3d.bias
#
# Mixed_4b.b2b.bn.running_mean   -> mixed_4b.branch_2.1.batch3d.running_mean
#
# Mixed_4b.b2b.bn.running_var    -> mixed_4b.branch_2.1.batch3d.running_var
#
# Mixed_4b.b3b.conv3d.weight     -> mixed_4b.branch_3.1.conv3d.weight
#
# Mixed_4b.b3b.bn.weight         -> mixed_4b.branch_3.1.batch3d.weight
#
# Mixed_4b.b3b.bn.bias           -> mixed_4b.branch_3.1.batch3d.bias
#
# Mixed_4b.b3b.bn.running_mean   -> mixed_4b.branch_3.1.batch3d.running_mean
#
# Mixed_4b.b3b.bn.running_var    -> mixed_4b.branch_3.1.batch3d.running_var
#
# Mixed_4f.b0.conv3d.weight      -> mixed_4f.branch_0.conv3d.weight
#
# Mixed_4f.b0.bn.weight          -> mixed_4f.branch_0.batch3d.weight
#
# Mixed_4f.b0.bn.bias            -> mixed_4f.branch_0.batch3d.bias
#
# Mixed_4f.b0.bn.running_mean    -> mixed_4f.branch_0.batch3d.running_mean
#
# Mixed_4f.b0.bn.running_var     -> mixed_4f.branch_0.batch3d.running_var
#
# Mixed_4f.b1a.conv3d.weight     -> mixed_4f.branch_1.0.conv3d.weight
#
# Mixed_4f.b1a.bn.weight         -> mixed_4f.branch_1.0.batch3d.weight
#
# Mixed_4f.b1a.bn.bias           -> mixed_4f.branch_1.0.batch3d.bias
#
# Mixed_4f.b1a.bn.running_mean   -> mixed_4f.branch_1.0.batch3d.running_mean
#
# Mixed_4f.b1a.bn.running_var    -> mixed_4f.branch_1.0.batch3d.running_var
#
# Mixed_4f.b1b.conv3d.weight     -> mixed_4f.branch_1.1.conv3d.weight
#
# Mixed_4f.b1b.bn.weight         -> mixed_4f.branch_1.1.batch3d.weight
#
# Mixed_4f.b1b.bn.bias           -> mixed_4f.branch_1.1.batch3d.bias
#
# Mixed_4f.b1b.bn.running_mean   -> mixed_4f.branch_1.1.batch3d.running_mean
#
# Mixed_4f.b1b.bn.running_var    -> mixed_4f.branch_1.1.batch3d.running_var
#
# Mixed_4f.b2a.conv3d.weight     -> mixed_4f.branch_2.0.conv3d.weight
#
# Mixed_4f.b2a.bn.weight         -> mixed_4f.branch_2.0.batch3d.weight
#
# Mixed_4f.b2a.bn.bias           -> mixed_4f.branch_2.0.batch3d.bias
#
# Mixed_4f.b2a.bn.running_mean   -> mixed_4f.branch_2.0.batch3d.running_mean
#
# Mixed_4f.b2a.bn.running_var    -> mixed_4f.branch_2.0.batch3d.running_var
#
# Mixed_4f.b2b.conv3d.weight     -> mixed_4f.branch_2.1.conv3d.weight
#
# Mixed_4f.b2b.bn.weight         -> mixed_4f.branch_2.1.batch3d.weight
#
# Mixed_4f.b2b.bn.bias           -> mixed_4f.branch_2.1.batch3d.bias
#
# Mixed_4f.b2b.bn.running_mean   -> mixed_4f.branch_2.1.batch3d.running_mean
#
# Mixed_4f.b2b.bn.running_var    -> mixed_4f.branch_2.1.batch3d.running_var
#
# Mixed_4f.b3b.conv3d.weight     -> mixed_4f.branch_3.1.conv3d.weight
#
# Mixed_4f.b3b.bn.weight         -> mixed_4f.branch_3.1.batch3d.weight
#
# Mixed_4f.b3b.bn.bias           -> mixed_4f.branch_3.1.batch3d.bias
#
# Mixed_4f.b3b.bn.running_mean   -> mixed_4f.branch_3.1.batch3d.running_mean
#
# Mixed_4f.b3b.bn.running_var    -> mixed_4f.branch_3.1.batch3d.running_var
#
# Mixed_5b.b0.conv3d.weight      -> mixed_5b.branch_0.conv3d.weight
#
# Mixed_5b.b0.bn.weight          -> mixed_5b.branch_0.batch3d.weight
#
# Mixed_5b.b0.bn.bias            -> mixed_5b.branch_0.batch3d.bias
#
# Mixed_5b.b0.bn.running_mean    -> mixed_5b.branch_0.batch3d.running_mean
#
# Mixed_5b.b0.bn.running_var     -> mixed_5b.branch_0.batch3d.running_var
#
# Mixed_5b.b1a.conv3d.weight     -> mixed_5b.branch_1.0.conv3d.weight
#
# Mixed_5b.b1a.bn.weight         -> mixed_5b.branch_1.0.batch3d.weight
#
# Mixed_5b.b1a.bn.bias           -> mixed_5b.branch_1.0.batch3d.bias
#
# Mixed_5b.b1a.bn.running_mean   -> mixed_5b.branch_1.0.batch3d.running_mean
#
# Mixed_5b.b1a.bn.running_var    -> mixed_5b.branch_1.0.batch3d.running_var
#
# Mixed_5b.b1b.conv3d.weight     -> mixed_5b.branch_1.1.conv3d.weight
#
# Mixed_5b.b1b.bn.weight         -> mixed_5b.branch_1.1.batch3d.weight
#
# Mixed_5b.b1b.bn.bias           -> mixed_5b.branch_1.1.batch3d.bias
#
# Mixed_5b.b1b.bn.running_mean   -> mixed_5b.branch_1.1.batch3d.running_mean
#
# Mixed_5b.b1b.bn.running_var    -> mixed_5b.branch_1.1.batch3d.running_var
#
# Mixed_5b.b2a.conv3d.weight     -> mixed_5b.branch_2.0.conv3d.weight
#
# Mixed_5b.b2a.bn.weight         -> mixed_5b.branch_2.0.batch3d.weight
#
# Mixed_5b.b2a.bn.bias           -> mixed_5b.branch_2.0.batch3d.bias
#
# Mixed_5b.b2a.bn.running_mean   -> mixed_5b.branch_2.0.batch3d.running_mean
#
# Mixed_5b.b2a.bn.running_var    -> mixed_5b.branch_2.0.batch3d.running_var
#
# Mixed_5b.b2b.conv3d.weight     -> mixed_5b.branch_2.1.conv3d.weight
#
# Mixed_5b.b2b.bn.weight         -> mixed_5b.branch_2.1.batch3d.weight
#
# Mixed_5b.b2b.bn.bias           -> mixed_5b.branch_2.1.batch3d.bias
#
# Mixed_5b.b2b.bn.running_mean   -> mixed_5b.branch_2.1.batch3d.running_mean
#
# Mixed_5b.b2b.bn.running_var    -> mixed_5b.branch_2.1.batch3d.running_var
#
# Mixed_5b.b3b.conv3d.weight     -> mixed_5b.branch_3.1.conv3d.weight
#
# Mixed_5b.b3b.bn.weight         -> mixed_5b.branch_3.1.batch3d.weight
#
# Mixed_5b.b3b.bn.bias           -> mixed_5b.branch_3.1.batch3d.bias
#
# Mixed_5b.b3b.bn.running_mean   -> mixed_5b.branch_3.1.batch3d.running_mean
#
# Mixed_5b.b3b.bn.running_var    -> mixed_5b.branch_3.1.batch3d.running_var
#
# Mixed_4c.b0.conv3d.weight      -> mixed_4c.branch_0.conv3d.weight
#
# Mixed_4c.b0.bn.weight          -> mixed_4c.branch_0.batch3d.weight
#
# Mixed_4c.b0.bn.bias            -> mixed_4c.branch_0.batch3d.bias
#
# Mixed_4c.b0.bn.running_mean    -> mixed_4c.branch_0.batch3d.running_mean
#
# Mixed_4c.b0.bn.running_var     -> mixed_4c.branch_0.batch3d.running_var
#
# Mixed_4c.b1a.conv3d.weight     -> mixed_4c.branch_1.0.conv3d.weight
#
# Mixed_4c.b1a.bn.weight         -> mixed_4c.branch_1.0.batch3d.weight
#
# Mixed_4c.b1a.bn.bias           -> mixed_4c.branch_1.0.batch3d.bias
#
# Mixed_4c.b1a.bn.running_mean   -> mixed_4c.branch_1.0.batch3d.running_mean
#
# Mixed_4c.b1a.bn.running_var    -> mixed_4c.branch_1.0.batch3d.running_var
#
# Mixed_4c.b1b.conv3d.weight     -> mixed_4c.branch_1.1.conv3d.weight
#
# Mixed_4c.b1b.bn.weight         -> mixed_4c.branch_1.1.batch3d.weight
#
# Mixed_4c.b1b.bn.bias           -> mixed_4c.branch_1.1.batch3d.bias
#
# Mixed_4c.b1b.bn.running_mean   -> mixed_4c.branch_1.1.batch3d.running_mean
#
# Mixed_4c.b1b.bn.running_var    -> mixed_4c.branch_1.1.batch3d.running_var
#
# Mixed_4c.b2a.conv3d.weight     -> mixed_4c.branch_2.0.conv3d.weight
#
# Mixed_4c.b2a.bn.weight         -> mixed_4c.branch_2.0.batch3d.weight
#
# Mixed_4c.b2a.bn.bias           -> mixed_4c.branch_2.0.batch3d.bias
#
# Mixed_4c.b2a.bn.running_mean   -> mixed_4c.branch_2.0.batch3d.running_mean
#
# Mixed_4c.b2a.bn.running_var    -> mixed_4c.branch_2.0.batch3d.running_var
#
# Mixed_4c.b2b.conv3d.weight     -> mixed_4c.branch_2.1.conv3d.weight
#
# Mixed_4c.b2b.bn.weight         -> mixed_4c.branch_2.1.batch3d.weight
#
# Mixed_4c.b2b.bn.bias           -> mixed_4c.branch_2.1.batch3d.bias
#
# Mixed_4c.b2b.bn.running_mean   -> mixed_4c.branch_2.1.batch3d.running_mean
#
# Mixed_4c.b2b.bn.running_var    -> mixed_4c.branch_2.1.batch3d.running_var
#
# Mixed_4c.b3b.conv3d.weight     -> mixed_4c.branch_3.1.conv3d.weight
#
# Mixed_4c.b3b.bn.weight         -> mixed_4c.branch_3.1.batch3d.weight
#
# Mixed_4c.b3b.bn.bias           -> mixed_4c.branch_3.1.batch3d.bias
#
# Mixed_4c.b3b.bn.running_mean   -> mixed_4c.branch_3.1.batch3d.running_mean
#
# Mixed_4c.b3b.bn.running_var    -> mixed_4c.branch_3.1.batch3d.running_var
#
# Conv3d_1a_7x7.conv3d.weight    -> conv3d_1a_7x7.conv3d.weight
#
# Conv3d_1a_7x7.bn.weight        -> conv3d_1a_7x7.batch3d.weight
#
# Conv3d_1a_7x7.bn.bias          -> conv3d_1a_7x7.batch3d.bias
#
# Conv3d_1a_7x7.bn.running_mean  -> conv3d_1a_7x7.batch3d.running_mean
#
# Conv3d_1a_7x7.bn.running_var   -> conv3d_1a_7x7.batch3d.running_var
#
# Mixed_3c.b0.conv3d.weight      -> mixed_3c.branch_0.conv3d.weight
#
# Mixed_3c.b0.bn.weight          -> mixed_3c.branch_0.batch3d.weight
#
# Mixed_3c.b0.bn.bias            -> mixed_3c.branch_0.batch3d.bias
#
# Mixed_3c.b0.bn.running_mean    -> mixed_3c.branch_0.batch3d.running_mean
#
# Mixed_3c.b0.bn.running_var     -> mixed_3c.branch_0.batch3d.running_var
#
# Mixed_3c.b1a.conv3d.weight     -> mixed_3c.branch_1.0.conv3d.weight
#
# Mixed_3c.b1a.bn.weight         -> mixed_3c.branch_1.0.batch3d.weight
#
# Mixed_3c.b1a.bn.bias           -> mixed_3c.branch_1.0.batch3d.bias
#
# Mixed_3c.b1a.bn.running_mean   -> mixed_3c.branch_1.0.batch3d.running_mean
#
# Mixed_3c.b1a.bn.running_var    -> mixed_3c.branch_1.0.batch3d.running_var
#
# Mixed_3c.b1b.conv3d.weight     -> mixed_3c.branch_1.1.conv3d.weight
#
# Mixed_3c.b1b.bn.weight         -> mixed_3c.branch_1.1.batch3d.weight
#
# Mixed_3c.b1b.bn.bias           -> mixed_3c.branch_1.1.batch3d.bias
#
# Mixed_3c.b1b.bn.running_mean   -> mixed_3c.branch_1.1.batch3d.running_mean
#
# Mixed_3c.b1b.bn.running_var    -> mixed_3c.branch_1.1.batch3d.running_var
#
# Mixed_3c.b2a.conv3d.weight     -> mixed_3c.branch_2.0.conv3d.weight
#
# Mixed_3c.b2a.bn.weight         -> mixed_3c.branch_2.0.batch3d.weight
#
# Mixed_3c.b2a.bn.bias           -> mixed_3c.branch_2.0.batch3d.bias
#
# Mixed_3c.b2a.bn.running_mean   -> mixed_3c.branch_2.0.batch3d.running_mean
#
# Mixed_3c.b2a.bn.running_var    -> mixed_3c.branch_2.0.batch3d.running_var
#
# Mixed_3c.b2b.conv3d.weight     -> mixed_3c.branch_2.1.conv3d.weight
#
# Mixed_3c.b2b.bn.weight         -> mixed_3c.branch_2.1.batch3d.weight
#
# Mixed_3c.b2b.bn.bias           -> mixed_3c.branch_2.1.batch3d.bias
#
# Mixed_3c.b2b.bn.running_mean   -> mixed_3c.branch_2.1.batch3d.running_mean
#
# Mixed_3c.b2b.bn.running_var    -> mixed_3c.branch_2.1.batch3d.running_var
#
# Mixed_3c.b3b.conv3d.weight     -> mixed_3c.branch_3.1.conv3d.weight
#
# Mixed_3c.b3b.bn.weight         -> mixed_3c.branch_3.1.batch3d.weight
#
# Mixed_3c.b3b.bn.bias           -> mixed_3c.branch_3.1.batch3d.bias
#
# Mixed_3c.b3b.bn.running_mean   -> mixed_3c.branch_3.1.batch3d.running_mean
#
# Mixed_3c.b3b.bn.running_var    -> mixed_3c.branch_3.1.batch3d.running_var
#
# Conv3d_2b_1x1.conv3d.weight    -> conv3d_2b_1x1.conv3d.weight
#
# Conv3d_2b_1x1.bn.weight        -> conv3d_2b_1x1.batch3d.weight
#
# Conv3d_2b_1x1.bn.bias          -> conv3d_2b_1x1.batch3d.bias
#
# Conv3d_2b_1x1.bn.running_mean  -> conv3d_2b_1x1.batch3d.running_mean
#
# Conv3d_2b_1x1.bn.running_var   -> conv3d_2b_1x1.batch3d.running_var
#
# Conv3d_2c_3x3.conv3d.weight    -> conv3d_2c_3x3.conv3d.weight
#
# Conv3d_2c_3x3.bn.weight        -> conv3d_2c_3x3.batch3d.weight
#
# Conv3d_2c_3x3.bn.bias          -> conv3d_2c_3x3.batch3d.bias
#
# Conv3d_2c_3x3.bn.running_mean  -> conv3d_2c_3x3.batch3d.running_mean
#
# Conv3d_2c_3x3.bn.running_var   -> conv3d_2c_3x3.batch3d.running_var

# %%
new_b_dict['logits.conv3d.weight'] = b['conv3d_0c_1x1.conv3d.weight']
new_b_dict['logits.conv3d.bias'] = b['conv3d_0c_1x1.conv3d.bias']

# %%
len(new_b_dict)

# %%
torch.save(new_b_dict, './pytorch_i3d/models/flow_kinetics.pth')
